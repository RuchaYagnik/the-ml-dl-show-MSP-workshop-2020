# %%
#importing all te req lib
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.preprocessing import image
import numpy as np
# Out:
# Using TensorFlow backend.

# %% [raw]
# observation={}

# %%
# dimensions of our images.
img_width, img_height = 128, 128

#defining the data directories
train_data_dir= 'data/train'
validation_data_dir= 'data/validation'
n_training_sample= 580
n_validation_sample= 100
epochs=10
batch_size=29

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %%
#defining the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Conv2D(64, (3,3), activation='relu', input_shape=(128, 128, 3)),
  tf.keras.layers.MaxPooling2D(2, 2),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(64, activation=tf.nn.relu),
  tf.keras.layers.Dense(16, activation=tf.nn.relu),
  tf.keras.layers.Dense(2, activation=tf.nn.sigmoid)])

# %%
#defining the optimizer and metrics
model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range=90.,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True)

# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

history = model.fit_generator(
    train_generator,
    steps_per_epoch=n_training_sample // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=n_validation_sample // batch_size)
# Out:
# Found 577 images belonging to 2 classes.
# Found 99 images belonging to 2 classes.
# Epoch 1/10
# 20/20 [==============================] - 143s 7s/step - loss: 0.3547 - accuracy: 0.8388 - val_loss: 0.5104 - val_accuracy: 0.7816
# Epoch 2/10
# 20/20 [==============================] - 106s 5s/step - loss: 0.3412 - accuracy: 0.8510 - val_loss: 0.7178 - val_accuracy: 0.7126
# Epoch 3/10
# 20/20 [==============================] - 101s 5s/step - loss: 0.4003 - accuracy: 0.8111 - val_loss: 0.7471 - val_accuracy: 0.6897
# Epoch 4/10
# 20/20 [==============================] - 107s 5s/step - loss: 0.3696 - accuracy: 0.8492 - val_loss: 0.4788 - val_accuracy: 0.7931
# Epoch 5/10
# 20/20 [==============================] - 91s 5s/step - loss: 0.3285 - accuracy: 0.8492 - val_loss: 0.7167 - val_accuracy: 0.7356
# Epoch 6/10
# 20/20 [==============================] - 94s 5s/step - loss: 0.3475 - accuracy: 0.8423 - val_loss: 0.8106 - val_accuracy: 0.6782
# Epoch 7/10
# 20/20 [==============================] - 97s 5s/step - loss: 0.3370 - accuracy: 0.8527 - val_loss: 1.0158 - val_accuracy: 0.6782
# Epoch 8/10
# 20/20 [==============================] - 106s 5s/step - loss: 0.3424 - accuracy: 0.8423 - val_loss: 0.6869 - val_accuracy: 0.6897
# Epoch 9/10
# 20/20 [==============================] - 106s 5s/step - loss: 0.3068 - accuracy: 0.8562 - val_loss: 0.6812 - val_accuracy: 0.7701
# Epoch 10/10
# 20/20 [==============================] - 99s 5s/step - loss: 0.3031 - accuracy: 0.8579 - val_loss: 0.8497 - val_accuracy: 0.7241

# %%
print(validation_generator.class_indices)
# Out:
# {'ice-cream': 0, 'waffle': 1}

# %%
#testing the model
pred= image.load_img('data/test/00000386.jpg', target_size=(32,32))
pred=image.img_to_array(pred)
pred= np.expand_dims(pred, axis=0)
result= model.predict(pred)
print(result)
print(result[0][0])
print(result[0][1])
# Out:
# [[0. 0.]]
# 0.0
# 0.0

# %%
if result[0][1]==1:
    answer='waffle'
else:
    answer='ice-cream'
print("The delicacy in the image is",answer, "!!")
# Out:
# The delicacy in the image is ice-cream !!

# %%
 import matplotlib. pyplot as plt 
    
# Loss Curves

plt.figure(figsize=[8,6])
plt.plot(history.history['loss'],'r',linewidth=2.0)
plt.plot(history.history['val_loss'],'b',linewidth=2.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=14)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Loss',fontsize=12)
plt.title('Loss Curves',fontsize=12) 

# Accuracy Curves
plt.figure(figsize=[8,6])
plt.plot(history.history['accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=14)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.title('Accuracy Curves',fontsize=12)
# Out:
# Text(0.5, 1.0, 'Accuracy Curves')

# %%
#create model
model2 = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(3, 32, 32), activation='relu', padding='same'))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(BatchNormalization())
    
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dropout(0.2))

model.add(Dense(256, kernel_constraint=maxnorm(3)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())
    
model.add(Dense(128, kernel_constraint=maxnorm(3)))
model.add(Activation('relu'))
model.add(Dropout(0.2))
model.add(BatchNormalization())

model.add(Dense(2))
model.add(Activation('sigmoid'))

# %%
#defining the optimizer and metrics
model.compile(optimizer = tf.optimizers.Adam(),
              loss = 'sparse_categorical_crossentropy',
              metrics=['accuracy'])
